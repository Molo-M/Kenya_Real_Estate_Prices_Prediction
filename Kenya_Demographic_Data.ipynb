# %% [markdown]
# # Kenya Real Estate Prices Prediction

# %% [markdown]
# ## Task: Collecting Demographic Data

# %% [markdown]
# ### Objectives
#
# Download demographic data from the Kenya 2019 Census and web scrape details about Counties and their Constituencies:
#
# * Download dataset containing demographic data
# * Using Selenium, extract County and Constituency information

# %% [markdown]
# Import useful libraries:

# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import time

# %% [markdown]
# Silence some of the selenium usage warnings about outdated function use.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Acquire dataset containing demographic data from the [Kenya 2019 Census](https://data.humdata.org/dataset/fa58ed8d-1daa-48b6-bae1-19746c32c85f) report.

# %%
df = pd.read_csv('https://data.humdata.org/dataset/fa58ed8d-1daa-48b6-bae1-19746c32c85f/resource/82f909ce-7358-48da-9639-8fe9c3318251/download/2019-population_census-report-per-county.csv')
df.head()
# Out:
#             County Total_Population19 Male populatio 2019  \
# 0          Baringo           666,763             336,322
# 1            Bomet           875,689             434,287
# 2          Bungoma         1,670,570             812,146
# 3            Busia           893,681             426,252
# 4  Elgeyo-Marakwet           454,480             227,317
#
#   Female population 2019 Households  Av_HH_Size  LandArea Population Density  \
# 0               330,428    142,518            5   10,976                 61
# 1               441,379    187,641            5    2,531                346
# 2               858,389    358,796            5    3,024                552
# 3               467,401    198,152            5    1,696                527
# 4               227,151     99,861            5    3,032                150
#
#   Population in 2009 Pop_change  Intersex population 2019
# 0           555,561    111,202                         13
# 1           724,186    151,503                         23
# 2         1,630,934     39,636                         35
# 3           488,075    405,606                         28
# 4           369,998     84,482                         12

# %%
df.to_csv('Population_by_county.csv')

# %% [markdown]
# Next, we will scrape data about counties and their constituencies in order to match them with the real estate data locations.

# %% [markdown]
# We will use the following webpage: [Fortune of Africa](https://fortuneofafrica.com/kenya/kenya-counties-and-constituencies/)

# %%
webpage = 'https://fortuneofafrica.com/kenya/kenya-counties-and-constituencies/'

# %% [markdown]
# Get webpage using selenium webdriver

# %%
driver = webdriver.Chrome('/Selenium Drivers/chromedriver.exe')
driver.get(webpage)

# %% [markdown]
# Store an array of the counties and their constituencies

# %%
# Get all the properties on the current page
page = driver.find_element_by_css_selector("div[class='entry-content clearfix']")
counties = page.find_elements_by_css_selector("p")

# Show the number of counties
print(f'Number of counties: {len(counties)}')
# Out:
# Number of counties: 47

# %% [markdown]
# Iterate through all the counties and save the information in a dictionary

# %%
print(f'These are the counties and their constituencies \n')

# dictionary to save county data
county_dict = dict()

for county in counties:
    info = county.text.split('Constituencies:')
    
    # county name
    county = info[0].strip().split('.')[1]
    print(f'County: {county}')
    
    # constituency
    const = info[1].strip().split(',')
    print(f'Constituencies: {const}, \n')
    
    # save the info in dictionary
    county_dict[f'{county}'] = const
# Out:
# These are the counties and their constituencies
#
# County: Baringo County
# Constituencies: ['Baringo East', ' Baringo West', ' Baringo Central', ' Mochongoi', ' Mogotio', ' Eldama Ravine.'],
#
# County: Bomet County
# Constituencies: ['Sotik', ' Chepalungu', ' Bomet East', ' Bomet Central', ' Konoin'],
#
# County: Bungoma County
# Constituencies: ['Mt. Elgon', ' Sirisia', ' Kabuchia', ' Bumula', ' Kandunyi', ' Webuye', ' Bokoli', ' Kimilili', ' Tongaren'],
#
# County: Busia County
# Constituencies: ['Teso North', ' Teso South', ' Nambale', ' Matayos', ' Butula', ' Funyula', ' Budalangi'],
#
# County: Elgeyo/Marakwet County
# Constituencies: ['Marakwet East', ' Marakwet West', ' Keiyo East', ' Keiyo South'],
#
# County:  Embu County
# Constituencies: ['Manyatta', ' Runyejes', ' Gachoka', ' Siakago'],
#
# County: Garissa County
# Constituencies: ['TaveDujis', ' Balambala', ' Lagdera', ' Dadaad', ' Fafi', ' Ijara'],
#
# County: Homa Bay County
# Constituencies: ['Kasipul', ' Kabondo', ' Karachuonyo', ' Rangwe', ' Homabay Town', ' Ndhiwa', ' Mbita', ' Gwassi'],
#
# County:  Isiolo County
# Constituencies: ['Isiolo North', ' Isiolo South'],
#
# County: Kajiado County
# Constituencies: ['Kajiado Central', ' Kajiado North', ' Kajiado South'],
#
# County: Kakamega County
# Constituencies: ['Lugari', ' Likuyani', ' Malava', ' Lurambi', ' Makholo', ' Mumias', ' Mumias East', ' Matungu', ' Butere', ' Khwisero', ' Shinyalu', ' ikolomani. Major Towns: Kakamega'],
#
# County: Kericho County
# Constituencies: ['Ainamoi', ' Belgut', ' Kipkelion'],
#
# County: Kiambu County
# Constituencies: ['Gatundu South', ' Gatundu North', ' Juja', ' Thika Town', ' Ruiru', ' Githunguri', ' Kiambu', ' Kiambaa', ' Kabete', ' Kikuyu', ' Limuru', ' Lari'],
#
# County: Kilifi County
# Constituencies: ['Kilifi North', ' Kilifi South', ' Kaloleni', ' Rabai', ' Ganze', ' Malindi', ' Magarini'],
#
# County: Kirinyaga County
# Constituencies: ['Mwea', ' Gichugu', ' Ndia', ' Kirinyaga'],
#
# County: Kisii County
# Constituencies: ['Bonchari', ' South Mugirango', ' Bomachoge', ' Bobasi', ' Gucha', ' Nyaribari Masaba', ' Nyaribari Chache', ' Matrani', ' Mosocho'],
#
# County: Kisumu County
# Constituencies: ['Kisumu East', ' Kisumu West', ' Kisumu Central', ' Seme', ' Nyando', ' Muhoroni', ' Nyakach'],
#
# County: Kitui County
# Constituencies: ['Mwingi North', ' Mwingi Central', ' Mwingi South', ' Kitui West', ' Kitui Rural', ' Kitui Town', ' Mutitu', ' Kitui South'],
#
# County: Kwale County
# Constituencies: ['Msambweni', ' Lunga Lunga', ' Matuga', ' Kinango'],
#
# County: Laikipia County
# Constituencies: ['Laikipia West', ' Laikipia Wast', ' Laikipia North'],
#
# County: Lamu County
# Constituencies: ['Lamu East', ' Lamu West'],
#
# County: Machakos County
# Constituencies: ['Masinga', ' Yatta', ' Kangundo', ' Mautungulu', ' Kathiani', ' Mavoko', ' Machakos Town', ' Mwala'],
#
# County: Makueni County
# Constituencies: ['Mbooni', ' Kilome', ' Kaiti', ' Makueni', ' Kibwezi West', ' Kibwezi East'],
#
# County: Mandera County
# Constituencies: ['Mandera West', ' Banisa', ' Mandera North', ' Mandera East', ' Mandera South', ' Lafey'],
#
# County: Marsabit County
# Constituencies: ['Moyale', ' North Horr', ' Saku', ' Laisamis'],
#
# County: Meru County
# Constituencies: ['Igembe South', ' Igembe Central', ' Igembe North', ' Tigania West', ' Tigania East', ' North Imenti', ' Mbuuri', ' Cenral Imenti', ' South Imenti'],
#
# County: Migori County
# Constituencies: ['Rongo', ' Awendo', ' Migori East Migori West', ' Uriri', ' Nyatike', ' Kuria East', ' Kuria West'],
#
# County: Mombasa County
# Constituencies: ['Changamwe', ' Jomvu', ' Kisauni', ' Nyali', ' likoni', ' Mvita Kwale'],
#
# County: Murang’a County
# Constituencies: ['Kangema', ' Mathioya', ' Kiharu', ' Kigumo', ' Maragwa', ' Kandara', ' Gatanga'],
#
# County: Nairobi County
# Constituencies: ['Westlands', ' Parklands', ' Dagoretti', ' Karwen / Langata', ' Kibira', ' Roysambu', ' Kasarani', ' Ruaraka', ' Kariobangi', ' kayole', ' Embakasi', ' Mihango', ' Nairobi West', ' Makadara', ' kamukunii', ' Starehe', ' Mathare'],
#
# County: Nakuru County
# Constituencies: ['Molo', ' Njoro', ' Naivasha', ' Gilgil', ' Kuresoi Aouth', ' Kuresoi North', ' Subukia', ' Rongai', ' Bahati', ' Nakuru Town West', ' Nakuru Town East.'],
#
# County: Nandi County
# Constituencies: ['Tinderet', ' Aldai', ' Nandi Hills', ' Emgwen North', ' Emgwen South', ' Mosop.'],
#
# County: Narok County
# Constituencies: ['Kilgoris', ' Emurua Dikirr', ' Narok North', ' Kajiado East', ' Kajiado West.'],
#
# County: Nyamira County
# Constituencies: ['Kitutu Masaba', ' North Mugirango', ' West Mugirango.'],
#
# County: Nyandarua County
# Constituencies: ['Kinangop', ' Kipipiri', ' Ol-Kalou', ' Ol-Jorok', ' Ndaragwa'],
#
# County: Nyeri County
# Constituencies: ['Tetu', ' Kieni', ' Mathira', ' Othaya', ' Mukuwe-ini', ' Nyeri Town'],
#
# County:  Samburu County
# Constituencies: ['Samburu West', ' Samburu North', ' Samburu East'],
#
# County: Siaya County
# Constituencies: ['Ugenya', ' Ugunja', ' Alego Usonga', ' Gem', ' Bondo', ' Rarieda'],
#
# County: Taita Taveta County
# Constituencies: ['Taveta', ' Wundanyi', ' Mwatate', ' Voi'],
#
# County: Tana River County
# Constituencies: ['Garsen', ' Galole', ' Bura'],
#
# County: Tharaka Nithi County
# Constituencies: ['Nithi', ' Maara', ' Tharaka'],
#
# County: Trans Nzoia County
# Constituencies: ['Kwanza', ' Endebess', ' Saboti', ' Kiminini', ' Cherenganyi'],
#
# County: Turkana County
# Constituencies: ['Turkana North', ' Turkana West', ' Turkana Central', ' Loima', ' Turkana South', ' Turkana East.'],
#
# County: Uasin Gishu County
# Constituencies: ['Eldoret East', ' Eldoret North and Eldoret South.'],
#
# County: Vihiga County
# Constituencies: ['Vihiga', ' Sabatia', ' Hamisi', ' Emuhaya', ' Luanda'],
#
# County: Wajir County
# Constituencies: ['Wajir North', ' Wajir East', ' Tarbaj', ' Wajir West', ' Eldas', ' Wajir South'],
#
# County: West Pokot County
# Constituencies: ['Kapenguri', ' Sigor', ' Kacheliba', ' Poko South'],

# %% [markdown]
# Save dictionary information in pandas dictionary

# %%
df = pd.DataFrame.from_dict(county_dict, orient='index').T
df
# Out:
#       Baringo County    Bomet County Bungoma County Busia County  \
# 0       Baringo East           Sotik      Mt. Elgon   Teso North
# 1       Baringo West      Chepalungu        Sirisia   Teso South
# 2    Baringo Central      Bomet East       Kabuchia      Nambale
# 3          Mochongoi   Bomet Central         Bumula      Matayos
# 4            Mogotio          Konoin       Kandunyi       Butula
# 5     Eldama Ravine.            None         Webuye      Funyula
# 6               None            None         Bokoli    Budalangi
# 7               None            None       Kimilili         None
# 8               None            None       Tongaren         None
# 9               None            None           None         None
# 10              None            None           None         None
# 11              None            None           None         None
# 12              None            None           None         None
# 13              None            None           None         None
# 14              None            None           None         None
# 15              None            None           None         None
# 16              None            None           None         None
#
#    Elgeyo/Marakwet County  Embu County Garissa County Homa Bay County  \
# 0           Marakwet East     Manyatta      TaveDujis         Kasipul
# 1           Marakwet West     Runyejes      Balambala         Kabondo
# 2              Keiyo East      Gachoka        Lagdera     Karachuonyo
# 3             Keiyo South      Siakago         Dadaad          Rangwe
# 4                    None         None           Fafi    Homabay Town
# 5                    None         None          Ijara          Ndhiwa
# 6                    None         None           None           Mbita
# 7                    None         None           None          Gwassi
# 8                    None         None           None            None
# 9                    None         None           None            None
# 10                   None         None           None            None
# 11                   None         None           None            None
# 12                   None         None           None            None
# 13                   None         None           None            None
# 14                   None         None           None            None
# 15                   None         None           None            None
# 16                   None         None           None            None
#
#     Isiolo County   Kajiado County  ...   Siaya County Taita Taveta County  \
# 0    Isiolo North  Kajiado Central  ...         Ugenya              Taveta
# 1    Isiolo South    Kajiado North  ...         Ugunja            Wundanyi
# 2            None    Kajiado South  ...   Alego Usonga             Mwatate
# 3            None             None  ...            Gem                 Voi
# 4            None             None  ...          Bondo                None
# 5            None             None  ...        Rarieda                None
# 6            None             None  ...           None                None
# 7            None             None  ...           None                None
# 8            None             None  ...           None                None
# 9            None             None  ...           None                None
# 10           None             None  ...           None                None
# 11           None             None  ...           None                None
# 12           None             None  ...           None                None
# 13           None             None  ...           None                None
# 14           None             None  ...           None                None
# 15           None             None  ...           None                None
# 16           None             None  ...           None                None
#
#    Tana River County Tharaka Nithi County Trans Nzoia County  \
# 0             Garsen                Nithi             Kwanza
# 1             Galole                Maara           Endebess
# 2               Bura              Tharaka             Saboti
# 3               None                 None           Kiminini
# 4               None                 None        Cherenganyi
# 5               None                 None               None
# 6               None                 None               None
# 7               None                 None               None
# 8               None                 None               None
# 9               None                 None               None
# 10              None                 None               None
# 11              None                 None               None
# 12              None                 None               None
# 13              None                 None               None
# 14              None                 None               None
# 15              None                 None               None
# 16              None                 None               None
#
#       Turkana County                 Uasin Gishu County Vihiga County  \
# 0      Turkana North                       Eldoret East        Vihiga
# 1       Turkana West   Eldoret North and Eldoret South.       Sabatia
# 2    Turkana Central                               None        Hamisi
# 3              Loima                               None       Emuhaya
# 4      Turkana South                               None        Luanda
# 5      Turkana East.                               None          None
# 6               None                               None          None
# 7               None                               None          None
# 8               None                               None          None
# 9               None                               None          None
# 10              None                               None          None
# 11              None                               None          None
# 12              None                               None          None
# 13              None                               None          None
# 14              None                               None          None
# 15              None                               None          None
# 16              None                               None          None
#
#     Wajir County West Pokot County
# 0    Wajir North         Kapenguri
# 1     Wajir East             Sigor
# 2         Tarbaj         Kacheliba
# 3     Wajir West        Poko South
# 4          Eldas              None
# 5    Wajir South              None
# 6           None              None
# 7           None              None
# 8           None              None
# 9           None              None
# 10          None              None
# 11          None              None
# 12          None              None
# 13          None              None
# 14          None              None
# 15          None              None
# 16          None              None
#
# [17 rows x 47 columns]

# %% [markdown]
# Save dataframe to csv file

# %%
df.to_csv('county_constituencies.csv')

# %%
# quit selenium driver
driver.quit()

# %% [markdown]
# ## Authors
#
# <a href="https://www.linkedin.com/in/molomunyansanga/">Molo Munyansanga</a> is a Data Science enthusiast with certificates in Statistics, Data Science and Machine Learning. He is also enrolled in the Deep Learning Specialization by DeepLearning.AI

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By    | Change Description      |
# | ----------------- | ------- | ------------- | ----------------------- |
# | 2022-04-12        | 1.3       | Molo. M       | Created Notebook and Completed Tasks         |
